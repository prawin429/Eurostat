# %%
import eurostat
StartPeriod = 2015
EndPeriod = 2020
filter_pars = {'FREQ': ['A',], 'PRCCODE': ['23511210','23511100','23511290'], 'DECL': ['004'], 'INDICATORS': ['PRODQNT','PRODVAL']}
df = eurostat.get_sdmx_data_df('DS-066341', StartPeriod, EndPeriod, filter_pars, flags = True, verbose=True)
# Out:
# Progress: 100.0%

# %%
df
# Out:
#     PRCCODE DECL INDICATORS FREQ           2015 2015_OBS_STATUS  \
# 0  23511210  004    PRODQNT    A   1.7037509E10
# 1  23511210  004    PRODVAL    A  1.125052397E9
# 2  23511100  004    PRODQNT    A     1.153575E9
# 3  23511100  004    PRODVAL    A    4.2657752E7
# 4  23511290  004    PRODQNT    A   1.4122835E10
# 5  23511290  004    PRODVAL    A   9.68678031E8
#
#             2016 2016_OBS_STATUS           2017 2017_OBS_STATUS  \
# 0   1.7503932E10                    1.791648E10
# 1  1.141951401E9                  1.172593314E9
# 2     1.129354E9                     1.210745E9
# 3    4.2185313E7                    4.5025457E7
# 4   1.5233454E10                    1.607467E10
# 5  1.016813928E9                  1.059530546E9
#
#             2018 2018_OBS_STATUS           2019 2019_OBS_STATUS  \
# 0   1.7734935E10                   1.7991419E10
# 1  1.201565497E9                  1.265388635E9
# 2     1.263038E9                     1.255477E9
# ...

# %%
import eurostat
StartPeriod = 2015
EndPeriod = 2020
filter_pars = {'FREQ': ['A',], 'PRCCODE': ['23511210','23511100','23511290'], 'DECL': ['005'], 'INDICATORS': ['PRODQNT','PRODVAL']}
df1 = eurostat.get_sdmx_data_df('DS-066341', StartPeriod, EndPeriod, filter_pars, flags = True, verbose=True)
# Out:
# Progress: 100.0%

# %%
df1
# Out:
#     PRCCODE DECL INDICATORS FREQ          2015 2015_OBS_STATUS          2016  \
# 0  23511210  005    PRODQNT    A  1.8523327E10                  1.9112573E10
# 1  23511210  005    PRODVAL    A    1.058696E9                    1.062258E9
# 2  23511100  005    PRODQNT    A    1.421675E9                    1.372043E9
# 3  23511100  005    PRODVAL    A      5.2159E7                      5.0227E7
# 4  23511290  005    PRODQNT    A    1.386259E9                     6.17499E8
# 5  23511290  005    PRODVAL    A       7.732E7                      6.5139E7
#
#   2016_OBS_STATUS          2017 2017_OBS_STATUS          2018 2018_OBS_STATUS  \
# 0                  2.4201419E10                  1.7193676E10
# 1                    1.367639E9                    1.007172E9
# 2                    1.826678E9                    1.320345E9
# 3                      6.2819E7                      4.6673E7
# 4                     9.03465E8                    1.212634E9
# ...

# %%
import pandas as pd
writer = pd.ExcelWriter('cement.xlsx', engine='xlsxwriter')

# %%
df.to_excel(writer, sheet_name='Germany')
df1.to_excel(writer, sheet_name='Italy')

# %%
writer.save()
